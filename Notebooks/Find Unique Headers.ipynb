# %% [markdown]
# ## Introduction

# %% [markdown]
# In this notebook, we will try to obtain the unique headers amongst all the csv files that we are going to merge. Then we will finally make a master comma seperated value file with list of headers that we obtain from this notebook

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Import the necessary libaries

# %%
import pandas as pd
import numpy as np
import glob
import csv
import os

# %% [markdown]
# ### Setting up parent directory and sub directory

# %%
parent_dir = "../Data/"
filelist = []

def makefilelist(parent_dir):
    headers = []
    csv_headers = []
    subject_dirs = [os.path.join(parent_dir, dir) for dir in os.listdir(parent_dir) if os.path.isdir(os.path.join(parent_dir, dir))]
    filelist = []
    for dir in subject_dirs:
        csv_files = [os.path.join(dir, csv) for csv in os.listdir(dir) if os.path.isfile(os.path.join(dir, csv)) and csv.endswith('.csv')]
        for file in csv_files:
            filelist.append(file)
    
    return filelist

# %% [markdown]
# ### Read headers from CSV files

# %%
def readCSV(fileList):
    master_csv_headers = []
    for filename in fileList:
        with open(filename, 'r') as f:
            d_reader = csv.DictReader(f)
            headers = d_reader.fieldnames
            for header in headers:
                master_csv_headers.append(header)
                
    return master_csv_headers

# %%
filelist = makefilelist(parent_dir)
csv_headers = readCSV(filelist)

# %% [markdown]
# Now we will only use the unqiue headers that we might require for our master CSV

# %%
def uniqueHeaders(csv_headers):
    return list(set(csv_headers))

def chomp(list1):
    list1 = [x.replace('\n', '') for x in list1]
    return list1

# %% [markdown]
# Checking our unique header values and taking a look on the kind of values we have

# %%
final_headers = uniqueHeaders(csv_headers)
lol = chomp(final_headers)
print(lol)
# Out:
# ['', 'UNREALIZED\xa0DEPRECIATION\xa0  ', 'Payments\xa0Received\xa0by\xa0Fund', '\ufeffReference Entity/Swap Counterparty', 'Reference Entity/Obligation', 'Notional Amount(1)', 'Rating of Reference Debt Obligation*', 'Notional amount\xa0', 'Premium(Received)Paid', 'Upfront Payments', 'Notional Amount1', 'Expiration Date', 'UNREALIZEDAPPRECIATION(DEPRECIATION)(000s)', 'Value($)', '(000 s)', 'Rate Paid by the Fund', 'Unrealized Depreciation ($)', 'Fixed Rate', '\xa0 NOTIONAL AMOUNT\xa0 \xa0 ', 'ImpliedCreditSpread\xa0atJune\xa030,2015(%)(d)', 'CreditSpread', 'Receive Fixed\xa0Rate', 'BUY/SELL\xa0 PROTECTION ', 'CurrentCreditSpread\xa0(10)', 'Notional Amount(c)', 'Payments made by the Fund', 'Bilateral Credit Default Swap Agreements (unrealized depreciation)', 'Termination\xa0 date\xa0', 'Underlying Debt\xa0Obligation', 'FixedRate', 'UnamortizedUp\xa0FrontPremiumPaid/(Received)', 'Notional  Amount   (000)', 'Maturity Date\xa0', 'Fixed         Payments         Made by         the Fund', 'Expiration  Date', '\xa0\xa0 ', 'UnderlyingInstrument', 'Fixed Rate (%)', 'PREMIUMSPAID/RECEIVED', '', 'Termination Date', 'NotionalAmount ($)', 'Unrealized\xa0 Loss\xa0\t', 'Rate(%)', 'Receive/PayFixed\xa0Rate', 'Unrealized   Appreciation   (Depreciation)', 'NetUnrealizedAppreciation(Depreciation)', 'ReceiveBuy/SellProtection', 'Notional Amount (000 s)', 'Upfrontpayments(made)/received', 'INTERESTRATE', 'UpfrontPaymentsReceived', 'SWAP COUNTERPARTY &REFERENCE OBLIGATION', 'Unrealized', '\xa0\xa0\xa0\xa0Notional\xa0\xa0\xa0\xa0Value3', 'Notional\xa0Amount(1)\xa0\t', 'Fund Perspective', 'UNREALIZED APPRECIATION(DEPRECIATION)', 'UnrealizedAppreciation(Depreciation)(U.S.\xa0Dollars)\xa0(6)', 'Broker\xa0(Exchange)', 'UnderlyingBond', 'UnrealizedAppreciation\xa0($)', 'Underlying DebtObligation', 'FeesReceivable/(Payable)', 'NOTIONALAMOUNT(000 S)', 'UnrealizedDepreciation', 'MaximumPotentialAmount ofFuturePaymentsby the FundUnder theContract (2)', 'Unrealized Depreciation ($) ', 'NotionalAmount(000 s)b', 'ExpirationDate', 'TERMINATION', 'Spread (12', 'Upfront Payments Paid ($)', 'CREDITRATING OFREFERENCEOBLIGATION ', 'Notional amount', '(Depreciation', 'UpfrontPremiumsReceived', 'UnrealizedAppreciation(Depreciation)(000)', 'Notional amount (000)', 'Fair Value', 'Appreciation/(Depreciation) ', 'Credit Spread (8)', 'UpfrontPremiumsPaid/(Received)', 'PremiumReceived(Paid)', 'Market   Value3', 'Fair value(2)', 'Buy/Sell', 'ImpliedCreditSpread at06/30/20168', 'Payments\xa0madeby the Fund', 'Swap\xa0Referenced\xa0Obligation', 'NotionalValue', 'UnrealizedAppreciation/ (Depreciation)', 'UpfrontPremiumsPaid/(Received)($)', 'Pay/Receive  Fixed Rate', 'EXPIRATIONDATE', '(Pay)/ ReceiveFixed Rate\xa0', 'Currency', 'Paymentsreceived by thePortfolio', 'Description', 'Unrealized (Depreciation)', 'SWAP COUNTERPARTY & REFERENCE OBLIGATION', 'Reference Debt Obligation/Index', 'NOTIONAL AMOUNT\xa0', 'Notional    Amount2', 'Market Value', 'Counterparty    ', 'Payments\xa0Made\xa0by\xa0Fund', 'made', 'Interest Rate\xa0\t', 'Value', 'Net UnrealizedAppreciation(Depreciation)', 'Reference\xa0Entity', 'MarketValue', 'Buy/Sell  Protection (1)', 'Termination Date', 'NotionalAmount', 'Expiration\xa0', 'Expiration', 'Unrealized  Appreciation/  (Depreciation)', 'Value atMarch\xa031,2009(U.S.\xa0Dollars)', 'Underlying Debt Obligation/Quality Rating', 'NotionalAmount(000)', 'Value', 'Broker (Exchange)', 'Notional\xa0', 'FIXED RATE', 'Fixed      Payment      Made', 'UpfrontPaymentsMade ', 'UnrealizedAppreciation', 'Underlying Debt Obligation/ Quality Rating\xa0(e)', 'VALUE', 'Paymentsreceivedby\xa0the\xa0Fund', '\ufeffSwap Reference Entity', 'Fixed Rate(%)', 'Swap\xa0Counterparty', 'NotionalAmount($)(e)', 'MarketValue', 'Payments  Received  by Fund', 'Referenced Entity', 'UnamortizedPremium(Paid)Received\xa0($)', 'Effective/Expiration Date', 'Termination Date', 'Buy/Sell', 'Value(000)', 'Terminationdate', 'Payment Termination Date', 'FUND\xa0', 'Appreciation\xa0', 'Buy/Sell', 'Credit Eve ...

# %%
for header in lol:
    if '0' in header:
        print(header)
# Out:
# UNREALIZEDAPPRECIATION(DEPRECIATION)(000s)
# (000 s)
# ImpliedCreditSpread atJune 30,2015(%)(d)
# CurrentCreditSpread (10)
# Notional  Amount   (000)
# Notional Amount (000 s)
# NOTIONALAMOUNT(000 S)
# NotionalAmount(000 s)b
# UnrealizedAppreciation(Depreciation)(000)
# Notional amount (000)
# ImpliedCreditSpread at06/30/20168
# Value atMarch 31,2009(U.S. Dollars)
# NotionalAmount(000)
# Value(000)
# AMOUNT (000 S)
# NotionalAmount(000)(4)
# PREMIUMSPAID/(RECEIVED)(000s)
# NotionalAmount (000)
# Notional Amount(000)
# NOTIONALAMOUNT(000)
# Notional Amount(000 s)
# AMOUNT(000 S)
# Amount (000)
# Implied Credit Spread at December 31, 2016(b)
# Upfront  Payments  (000)
# ImpliedCreditSpread atJune 30,2014(%)(d)
# NotionalAmount(000)
# NOTIONALAMOUNT(000's)
# Amount(000)
# CreditReceivedat4/30/2015
# UpfrontPaymentPaid(Received)(000)
# Notional Amount (000s)
# Amount(000)
# Credit Spread (10)
# Amount(000s)
# Notional Amount(000s)
# ImpliedCreditSpread atJune 30,2014(%)(d)
# (107,967
# ImpliedCreditSpread at5/31/201510
# Amount(000 s)
# Notional Amount (000s)
# AMOUNT (000 s)
# NOTIONALAMOUNT(000'S)
# NOTIONALAMOUNT(000)
# Notional  Amount  (000)
# AMOUNT (000 S)
# Notional Amount (000)
# Notionalamount(000)
# ImpliedCreditSpread atJune 30,
# NOTIONAL AMOUNT (000's)
# Notional Amount(000's)
# Amount (000)
# NOTIONAL AMOUNT (000 s)
# CDX NA Investment Grade    Index-10 6/20/13
# ImpliedCreditSpread atJune 30,2013(n)
# NotionalAmount(000)2
# Unrealized  Appreciation  (Depreciation)  (000)
# NOTIONALAMOUNT (000)
# Notional  Amount  Payable on  Default  (000)
# ImpliedCreditSpread atApril 30,2009(3)
# FAIR VALUE(000s)
# NotionalAmount(000'somitted)

# %%
def normalizeValues(filelist):
    for filename in filelist:
        with open(filename, 'r') as f:
            df = pd.read_csv(filename, error_bad_lines=False)
            headers = list(df)
            for header in headers:
                if '000' in header:
                    df[header] = df[header].astype(str) + '000'
            print (df)
            print("Filename", filename)        
            df.to_csv(filename, index=False, header=True)

# %%
normalizeValues(filelist)
# Out:
#       Counterparty\n  \nNotional amount \nTermination date  \
# 0  Deutsche\nBank AG            2110000           06/20/16
#
#   \nUnrealized appreciation(depreciation)
# 0                                $152,115
# Filename ../Data/0000880943_N-CSRS_0001209286-07-000236/table2.csv
#        Swap Counterparty and\n  Reference Obligation Buy/Sell\n  Protection  \
# 0  Barclays Capital\n  Dow Jones CDX North Americ...                    Buy
# 1  Goldman Sachs\n  Dow Jones CDX North America I...                   Sell
# 2  JPMorgan Chase Dow\n  Jones CDX North America ...                   Sell
# 3  JPMorgan Chase Dow\n  Jones CDX North America ...                   Sell
# 4  JPMorgan Chase Dow\n  Jones CDX North America ...                   Sell
# 5  Barclays Capital\n  Dow Jones CDX North Americ...                    Buy
# 6  Goldman Sachs\n  Dow Jones CDX North America I...                   Sell
#
#   Notional\n  Amount \n  (000) Pay/Receive\n  Fixed Rate Termination\n  Date  \
# 0                    $7,710000                     0.60%            12/20/12
# 1                      7808000                      0.35             6/20/12
# 2                      9000000                     1.50%            12/20/13
# 3                       nan000                     1.50%            12/20/13
# 4                       nan000                     1.50%            12/20/13
# 5                    $7,710000                     0.60%            12/20/12
# 6                      7808000                      0.35             6/20/12
#
#   Upfront\n  Payments\n  (000)  \
# 0                      $258000
# 1                       111000
# 2                   $195.00000
# 3                      $195000
# 4                      $195000
# 5                      $258000
# 6                       111000
#
#   Unrealized\n  Appreciation\n  (Depreciation)\n  (000)
# 0                                           $(283000
# 1                                            (441000
# 2                                             nan000
# 3                                           $(134000
# 4                                           $(134000
# 5                                           $(283000
# 6                                            (441000
# Filename ../Data/0000741375_N-CSRS_0001104659-09-037106/combined.csv
#   NotionalAmount ExpirationDate         Counterparty Buy/SellProtection  \
# 0      4,800,000       10/12/52  Goldman Sachs & Co.                Buy
# 1      5,525,000       10/12/52  Goldman Sachs & Co.                Buy
# 2      5,525,000       10/12/52  Goldman Sachs & Co.                Buy
# 3     13,300,000       10/12/52  Goldman Sachs & Co.                Buy
# 4      4,600,000       10/12/52  Goldman Sachs & Co.                Buy
#
#   Receive(Pay)FixedRate Deliverable on Default  \
# 0                (0.100          CMBX.NA.AAA.1
# 1                (0.100          CMBX.NA.AAA.1
# 2                (0.100          CMBX.NA.AAA.1
# 3                (0.100          CMBX.NA.AAA.1
# 4                (0.100          CMBX.NA.AAA.1
#
#   UnrealizedAppreciation(Depreciation) Premium(Received)Paid    Value
# 0                              (91,213               264,013  172,800
# 1                              (91,178               290,078  198,900
# 2                             (118,803               317,703  198,900
# 3                             (485,487               964,287  478,800
# 4                             (167,913               333,513  165,600
# Filename ../Data/0001317146_N-CSRS_0001193125-12-375855/table4.csv
#    NotionalAmount ExpirationDate                  Counterparty  \
# 0       2,300,000        6/20/17             Barclays Bank PLC
# 1         775,000        6/20/16  Credit Suisse Securities LLC
# 2       4,850,000        6/20/17           Goldman Sachs & Co.
# 3       3,145,000       10/12/52           Goldman Sachs & Co.
# 4         365,000       10/12/52           Goldman Sachs & Co.
# 5         950,000       10/12/52           Goldman Sachs & Co.
# 6         400,000       10/12/52           Goldman Sachs & Co.
# 7         850,000       10/12/52           Goldman Sachs & Co.
# 8       2,300,000       10/12/52           Goldman Sachs & Co.
# 9         300,000       10/12/52           Goldman Sachs & Co.
# 10      1,100,000       10/12/52           Goldman Sachs & Co.
# 11      3,100,000       10/12/52           Goldman Sachs & Co.
# 12      1,350,000       10/12/52           Goldman Sachs & Co.
# 13        925,000       10/12/52           Goldman Sachs & Co.
# 14     24,500,000        6/20/17             Barclays Bank PLC
# 15      1,125,000        6/20/16  Credit Suisse Securities LLC
# 16     19,250,000        6/20/17           Goldman Sachs & Co.
# 17      2,950,000       10/12/52           Goldman Sachs & Co.
# 18     10,030,000       10/12/52           Goldman Sachs & Co.
# 19      4,200,000       10/12/52           Goldman Sachs & Co.
# 20      4,200,000       10/12/52           Goldman Sachs & Co.
# 21      4,575,000       10/12/52           Goldman Sachs & Co.
#
#    Buy/SellProtection Receive(Pay)FixedRate        Deliverable on Default  \
# 0                 Buy                (1.000                  CDX.NA.IG.18
# 1                 Buy                (0.580  Marriott International, Inc.
# 2                 Buy                (1.000                  CDX.NA.IG.18
# 3                 Buy                (0.100                 CMBX.NA.AAA.1
# 4                 Buy                (0.100                 CMBX.NA.AAA.1
# 5                 Buy                (0.100                 CMBX.NA.AAA.1
# 6                 Buy                (0.100                 CMBX.NA.AAA.1
# 7                 Buy                (0.100                 CMBX.NA.AAA.1
# 8                 Buy                (0.100                 CMBX.NA.AAA.1
# 9                 Buy                (0.100                 CMBX.NA.AAA.1
# 10                Buy                (0.100                 CMBX.NA.AAA.1
# 11                Buy                (0.100                 CMBX.NA.AAA.1
# 12                Buy                (0.100                 CMBX.NA.AAA.1
# 13                Buy                (0.100                 CMBX.NA.AAA.1
# 14                Buy                (1.000                  CDX.NA.IG.18
# 15                Buy                (0.580  Marriott International, Inc.
# 16                Buy                (1.000                  CDX.NA.IG.18
# 17                Buy                (0.100                 CMBX.NA.AAA.1
# 18                Buy                (0.100                 CMBX.NA.AAA.1
# 19                Buy                (0.100                 CMBX.NA.AAA.1
# 20                Buy                (0.100                 CMBX.NA.AAA.1
# 21                Buy                (0.100                 CMBX.NA.AAA.1
#
#    UnrealizedAppreciation(Depreciation) Premium(Received)Paid    Value
# 0                                (2,086                21,727   19,641
# 1                                11,257                     -   11,257
# 2                                34,563                 6,855   41,418
# 3                              (190,874               304,094  113,220
# 4                               (10,585                23,725   13,140
# 5                               (23,196                57,396   34,200
# 6                                (4,600                19,000   14,400
# 7                               (11,902                42,502   30,600
# 8                               (43,706               126,506   82,800
# 9                                (4,951                15,751   10,800
# 10                              (23,653                63,253   39,600
# 11                             (113,158               224,759  111,601
# 12                              (49,279                97,879   48,600
# 13                              (59,200                92,500   33,300
# 14                              (22,214               231,442  209,228
# 15                               16,340                     -   16,340
# 16                              137,185                27,210  164,395
# 17                             (188,800               295,000  106,200
# 18                             (608,733               969,813  361,080
# 19                             (121,800               273,000  151,200
# 20                             (102,550               253,750  151,200
# 21                              (52,612               217,312  164,700
# Filename ../Data/0001317146_N-CSRS_0001193125-12-375855/table2.csv
#   NotionalAmount ExpirationDate       Counterparty Buy/SellProtection  \
# 0     $2,350,000        6/20/17  Barclays Bank PLC                Buy
# 1      5,000,000        6/20/17  Barclays Bank PLC                Buy
# 2      5,000,000       10/12/52  Barclays Bank PLC                Buy
# 3      2,500,000       10/12/52  Barclays Bank PLC                Buy
# 4      6,000,000       10/12/52  Barclays Bank PLC                Buy
#
#   Receive(Pay) FixedRate Deliverable on Default  \
# 0               (1.000%)           CDX.NA.IG.18
# 1               (1.000%)           CDX.NA.IG.18
# 2               (0.100%)          CMBX.NA.AAA.1
# 3               (0.100%)          CMBX.NA.AAA.1
# 4               (0.100%)          CMBX.NA.AAA.1
#
#   UnrealizedAppreciation(Depreciation) Premium(Received)Paid    Value
# 0                               (2,131                22,200   20,069
# 1                               35,939                 6,760   42,699
# 2                             (107,514               287,514  180,000
# 3                              (85,007               175,007   90,000
# 4                               51,000               165,000  216,000
# Filename ../Data/0001317146_N-CSRS_0001193125-12-375855/table8.csv
#   Swap counterparty/ Referenced debt*   Rating***  \
# 0                  CMBX NA BBB  Index     BBB /P
# 1                  CMBX NA BBB  Index     BBB /P
#
#   Upfront premium received (paid)**  Notional Amount Termination  date
# 0                              $755         $98,000            1/17/47
# 1                               4162          139000           1/17/47
# Filename ../Data/0000822671_N-CSRS_0000928816-15-001250/table8.csv
#                 Counterparty(a) TerminationDate NotionalAmount(000) FixedRate  \
# 0   Merrill Lynch International          1/7/05             1500000     1.04%
# 1                Morgan Stanley        12/20/08              200000      0.26
# 2                           UBS        12/20/08              200000      0.35
# 3                      Barclays        12/20/08              100000      0.67
# 4                     Citigroup        12/20/08              200000      0.28
# 5         Bank of America, N.A.        12/20/08              100000      0.13
# 6                      Barclays        12/20/08              200000      0.16
# 7                Morgan Stanley        12/20/08              100000      0.21
# 8                     Citigroup        12/20/08              100000      0.29
# 9                  Bear Stearns        06/20/05             1700000      0.55
# 10             Bear Stearns (b)        06/20/05             1700000      0.69
# 11              Lehman Brothers        12/20/08              100000      0.97
# 12                 Bear Stearns        12/20/08              200000      0.32
# 13                Merrill Lynch        12/20/08              100000      0.32
# 14              Lehman Brothers        12/20/08              200000      0.11
# 15              Lehman Brothers        12/20/08              100000      0.53
# 16              Lehman Brothers        12/20/08              100000       0.3
# 17              Lehman Brothers        12/20/08              100000      0.48
# 18              Lehman Brothers        06/20/09              400000       0.4
# 19              Lehman Brothers        12/20/08              100000      0.35
# 20              Lehman Brothers        12/20/08              200000      0.12
# 21                     Barclays        12/20/08              100000      0.67
# 22                    Citigroup        12/20/08              300000      0.14
# 23              Lehman Brothers        12/20/08              100000      0.29
# 24               Morgan Stanley         6/20/09            4,000000     0.82%
#
#                                       Underlying Bond UnrealizedAppreciation
# 0              Russian Federation, 5.00%, due 3/31/30                   1516
# 1                 Allstate Corp., 6.125%, due 2/15/12                    (73
# 2                AutoZone, Inc., 5.875%, due 10/15/12                   1855
# 3   Clear Channel Communication, Inc., 7.65%, due ...                    311
# 4                     Eaton Corp., 5.75%, due 7/15/12                   (365
# 5   E.I. DuPont de Nemours & Co., 6.875%, due 10/1...                    248
# 6           Eli Lilly & Co., Inc., 6.00%, due 3/15/12                   (166
# 7          Emerson Electric Co., 4.625%, due 10/15/12                    124
# 8                     FedEx Corp., 7.25%, due 2/15/11                    356
# 9   General Motors Acceptance Corp., 6.875%, due 8...                   (424
# 10          General Motors Corp., 7.125%, due 7/15/13                   3236
# 11               Goodrich Corp., 7.625%, due 12/15/12                 (1,054
# 12             Hewlett Packard Co., 6.50%, due 7/1/12                   (287
# 13              Ingersoll-Rand Co., 6.48%, due 6/1/25                    271
# 14              Johnson & Johnson, 3.80%, due 5/15/13                    NaN
# 15          Lockheed Martin Corp., 8.20%, due 12/1/09                   (426
# 16                   Masco Corp., 5.875%, due 7/15/12                    578
# 17        Northrop Grumman Corp., 7.125%, due 2/15/11                   (179
# 18     People s Republic of China, 6.80%, due 5/23/11                    (54
# 19              RadioShack Corp., 7.375%, due 5/15/11                    150
# 20           The Home Depot, Inc., 5.375%, due 4/1/06                    166
# 21            The Walt Disney Co., 6.375%, due 3/1/12                   (733
# 22         Wal-Mart Stores, Inc., 6.875%, due 8/10/09                    124
# 23                 Whirlpool Corp., 8.60%, due 5/1/10                   1173
# 24  Tyco InternationalGroup, S.A.,6.00%, due 11/15/13                 48,993
# Filename ../Data/0000711175_N-CSRS_0001193125-04-152307/combined.csv
#   \n\nNotional Amount\n    \n\n \n\nExpiration Date\n    \n\n  \
# 0               \n    400,000\n              \n    12/20/10\n
# 1               \n    300,000\n              \n    12/20/10\n
# 2               \n    700,000\n              \n    12/20/10\n
# 3             \n    1,600,000\n              \n    12/20/19\n
# 4             \n    1,300,000\n              \n    12/20/19\n
# 5               \n    900,000\n              \n    03/20/16\n
# 6             \n    1,400,000\n              \n    03/20/16\n
# 7               \n    400,000\n              \n    12/20/15\n
#
#                       \n\nCounterparty\n    \n\n \n\nValue\n    \n\n
# 0            \n    Goldman Sachs International\n         \n    476\n
# 1                          \n    Citibank N.A.\n         \n    357\n
# 2                       \n    Deutsche Bank AG\n         \n    833\n
# 3                   \n    Bank Of America N.A.\n     \n    (16,460\n
# 4                                 \n    UBS AG\n     \n    (13,374\n
# 5                     \n    Deutsche Bank N.A.\n      \n    34,199\n
# 6  \n    Morgan Stanley Capital Services, Inc.\n      \n    53,197\n
# 7                       \n    Deutsche Bank AG\n      \n    12,864\n
# Filename ../Data/0001320615_N-CSRS_0000950123-10-111902/table3.csv
#                        \n\nUnderlying Instrument\n\n  \
# 0                        \n\n    Allstate Corp. \n\n
# 1              \n\n    Bristol-Myers Squibb Co. \n\n
# 2                           \n\n    Citibank N.A\n\n
# 3  \n\n    Emerging Markets CDX Indices, Series 1...
# 4  \n\n    Emerging Markets CDX Indices, Series 1...
# 5  \n\n    Emerging Markets CDX Indices, Series 1...
# 6          \n\n    Federative Republic of Brazil\n\n
# 7                          \n\n    Monsanto Co. \n\n
#
#                      \nCounterparty\n \nNotional Amount($)\n  \
# 0                    \n    JPMorgan\n          \n    2,265\n
# 1                    \n    JPMorgan\n          \n    2,265\n
# 2  \n    Credit Suisse First Boston\n          \n    2,330\n
# 3                    \n    Barclays\n          \n    8,201\n
# 4                    \n    JPMorgan\n          \n    6,599\n
# 5              \n    Morgan Stanley\n          \n    6,554\n
# 6              \n    Morgan Stanley\n          \n    4,999\n
# 7                    \n    JPMorgan\n          \n    2,265\n
#
#    \nFixed Rate(%)\n \nExpiration Date\n \nPayments Made/(Received)($)\n  \
# 0                1.0    \n    06/20/15\n                     \n    (29\n
# 1                1.0    \n    06/20/15\n                     \n    (61\n
# 2                1.0    \n    06/20/15\n                      \n    65\n
# 3                5.0    \n    12/20/15\n                  \n    (1,027\n
# 4                5.0    \n    12/20/15\n                    \n    (821\n
# 5                5.0    \n    12/20/15\n                    \n    (814\n
# 6                1.0    \n    12/20/15\n                      \n    48\n
# 7                1.0    \n    06/20/15\n                     \n    (49\n
#
#   \nAppreciation/(Depreciation)($)\n
# 0                         \n    24\n
# 1                         \n    (8\n
# 2                          \n    4\n
# 3                        \n    (49\n
# 4                        \n    (45\n
# 5                        \n    (46\n
# 6                        \n    (10\n
# 7                          \n    6\n
# Filename ../Data/0000883939_N-CSRS_0000950123-10-110787/table7.csv
#                        \n\nUnderlying Instrument\n\n  \
# 0                        \n\n    Allstate Corp. \n\n
# 1              \n\n    Bristol-Myers Squibb Co. \n\n
# 2                          \n\n    Citibank N.A.\n\n
# 3  \n\n    Emerging Markets CDX Indices, Series 1...
# 4  \n\n    Emerging Markets CDX Indices, Series 1...
# 5  \n\n    Emerging Markets CDX Indices, Series 1...
# 6          \n\n    Federative Republic of Brazil\n\n
# 7                          \n\n    Monsanto Co. \n\n
#
#                      \nCounterparty\n \nNotional Amount($)\n  \
# 0                    \n    JPMorgan\n          \n    8,680\n
# 1                    \n    JPMorgan\n          \n    8,680\n
# 2  \n    Credit Suisse First Boston\n          \n    8,525\n
# 3             \n    Bank of America\n         \n    31,664\n
# 4                    \n    JPMorgan\n         \n    25,545\n
# 5              \n    Morgan Stanley\n         \n    25,604\n
# 6              \n    Morgan Stanley\n         \n    19,059\n
# 7                    \n    JPMorgan\n          \n    8,680\n
#
#    \nFixed Rate(%)\n \nExpiration Date\n \nPayments Made/(Received)($)\n  \
# 0                1.0    \n    06/20/15\n                    \n    (103\n
# 1                1.0    \n    06/20/15\n                    \n    (212\n
# 2                1.0    \n    06/20/15\n                     \n    213\n
# 3                5.0    \n    12/20/15\n                  \n    (3,998\n
# 4                5.0    \n    12/20/15\n                  \n    (3,204\n
# 5                5.0    \n    12/20/15\n                  \n    (3,209\n
# 6                1.0    \n    12/20/15\n                     \n    178\n
# 7                1.0    \n    06/20/15\n                    \n    (173\n
#
#   \nAppreciation/(Depreciation)($)\n
# 0                         \n    85\n
# 1                        \n    (52\n
# 2                         \n    36\n
# 3                       \n    (156\n
# 4                       \n    (147\n
# 5                       \n    (151\n
# 6                        \n    (31\n
# 7                          \n    5\n
# Filename ../Data/0000883939_N-CSRS_0000950123-10-110787/table3.csv
#                        \n\nUnderlying Instrument\n\n  \
# 0          \n\n    Federative Republic of Brazil\n\n
# 1  \n\n    Emerging Markets CDX Indices, Series 1...
# 2  \n\n    Emerging Markets CDX Indices, Series 1...
# 3  \n\n    Emerging Markets CDX Indices, Series 1...
#
#             \nCounterparty\n \nNotional Amount($)\n  \nFixed Rate(%)\n  \
# 0     \n    Morgan Stanley\n          \n    8,320\n                1.0
# 1  \n    Barclays Bank PLC\n          \n    1,924\n                5.0
# 2           \n    JPMorgan\n            \n    955\n                5.0
# 3     \n    Morgan Stanley\n          \n    6,599\n                5.0
#
#   \nExpiration Date\n \nPayments Made/(Received)($)\n  \
# 0    \n    12/20/15\n                      \n    78\n
# 1    \n    12/20/15\n                    \n    (244\n
# 2    \n    12/20/15\n                    \n    (120\n
# 3    \n    12/20/15\n                    \n    (832\n
#
#   \nAppreciation/(Depreciation)($)\n
# 0                        \n    (14\n
# 1                         \n    (8\n
# 2                         \n    (5\n
# 3                        \n    (34\n
# Filename ../Data/0000883939_N-CSRS_0000950123-10-110787/table11.csv
#               COUNTERPARTY/  REFERENCE OBLIGATIONS   NOTIONAL AMOUNT2      \
# 0      Morgan Stanley  /Abitibi-Consolidated, Inc.           $3,000,000
# 1         Morgan Stanley  /American Airlines, Inc.                3000000
# 2        Lehman Brothers  /American Airlines, Inc.                2000000
# 3                      Morgan Stanley  / AMR Corp.                6000000
# 4                       Morgan Stanley  /AMR Corp.                5000000
# 5                  Morgan Stanley  / BoWater, Inc.                3000000
# 6            Morgan Stanley  /Delta Airlines, Inc.               10000000
# 7   Morgan Stanley  / Texas Competitive  Electric...             10000000
# 8   Morgan Stanley  / Texas Competitive  Electric...              5000000
# 9
#
#   BUY/SELL  PROTECTION  (PAY)/  RECEIVE  FIXED RATE   MATURITY  DATE    \
# 0                Sell                         8.00%         Sep 2012
# 1                Sell                             6.6       Sep 2012
# 2                Sell                               5       Mar 2013
# 3                Sell                               5       Sep 2010
# 4                Sell                               5       Sep 2010
# 5                Sell                               7       Sep 2012
# 6                Sell                               5       Sep 2013
# 7                Sell                             4.6       Jun 2013
# 8                Sell                            5.85       Jun 2013
# 9                   NaN                           NaN              NaN
#
#   UNREALIZED  APPRECIATION (DEPRECIATION)
# 0                             ($2,126,005)   NaN
# 1                              (1,357,093)   NaN
# 2                              (1,014,224)   NaN
# 3                              (2,366,123)   NaN
# 4                              (1,980,450)   NaN
# 5                              (1,790,881)   NaN
# 6                              (2,689,524)   NaN
# 7                              (1,943,439)   NaN
# 8                                (941,724)   NaN
# 9                                        NaN NaN
# Filename ../Data/0000315554_N-CSRS_0000928816-09-000133/table2.csv
#              \nCounterparty\n                        \nReference Instrument\n  \
# 0  \n\n    Morgan Stanley\n\n  \n    Eastman Kodak Co.\n    7.25%, 11/15/13\n
# 1  \n\n    Morgan Stanley\n\n  \n    Eastman Kodak Co.\n    7.25%, 11/15/13\n
# 2  \n\n    Morgan Stanley\n\n  \n    Eastman Kodak Co.\n    7.25%, 11/15/13\n
# 3   \n\n    Goldman Sachs\n\n         \n    Masco Corp.\n    6.13%, 10/3/16\n
# 4   \n\n    Merrill Lynch\n\n         \n    Masco Corp.\n    6.13%, 10/3/16\n
# 5  \n\n    Morgan Stanley\n\n         \n    Masco Corp.\n    6.13%, 10/3/16\n
#
#   \nNotional AmountB\n \nPay/Receive(A)\n  \nFixed Rate\n  \nExpirationDate\n  \
# 0    \n    3,000,000\n        \n    Pay\n             5.0   \n    6/20/2014\n
# 1    \n    1,000,000\n    \n    Receive\n             5.0   \n    9/20/2016\n
# 2    \n    3,000,000\n    \n    Receive\n             5.0   \n    6/20/2016\n
# 3      \n    500,000\n        \n    Pay\n             1.0  \n    12/20/2015\n
# 4      \n    500,000\n        \n    Pay\n             1.0   \n    3/20/2016\n
# 5    \n    1,000,000\n        \n    Pay\n             1.0   \n    3/20/2016\n
#
#   \nPaid (Received)\n \nAppreciation/(Depreciation)\n        \nCredit Event\n  \
# 0     \n    420,000\n                  \n    91,755\n  \n    Bankruptcy/FTP\n
# 1    \n    (280,000\n                   \n    9,528\n  \n    Bankruptcy/FTP\n
# 2    \n    (660,000\n                \n    (125,382\n  \n    Bankruptcy/FTP\n
# 3      \n    39,569\n                  \n    (9,416\n  \n    Bankruptcy/FTP\n
# 4      \n    30,352\n                   \n    4,131\n  \n    Bankruptcy/FTP\n
# 5      \n    66,735\n                  \n    10,698\n  \n    Bankruptcy/FTP\n
#
#   \nRating(C)\n
# 0   \n    CCC\n
# 1   \n    CCC\n
# 2   \n    CCC\n
# 3   \n    BBB\n
# 4   \n    BBB\n
# 5   \n    BBB\n
# Filename ../Data/0001016073_N-CSRS_0000950123-11-081936/table5.csv
#             \nCounterparty\n                         \nReference Instrument\n  \
# 0  \n\n    Goldman Sachs\n\n     \n    Tyson Foods, Inc.\n    6.85%, 4/1/16\n
# 1  \n\n    Goldman Sachs\n\n  \n    Vornado Realty L.P.\n    4.75%, 12/1/10\n
#
#   \nNotional AmountB\n \nPay/Receive(A)\n  \nFixed Rate\n \nExpirationDate\n  \
# 0    \n    6,000,000\n        \n    Pay\n            3.05  \n    9/20/2013\n
# 1    \n    5,500,000\n        \n    Pay\n            1.50  \n    6/20/2013\n
#
#   \nAppreciation/(Depreciation)\n                            \nCredit Event\n  \
# 0                \n    (307,749\n                      \n    Bankruptcy/FTP\n
# 1                \n    (112,811\n  \n    Restructuring/\n    Bankruptcy/FTP\n
#
#     \nRatingC\n
# 0  \n    BBB-\n
# 1   \n    BBB\n
# Filename ../Data/0001016073_N-CSRS_0000950123-11-081936/table3.csv
#               \nCounterparty\n  \
# 0    \n\n    Goldman Sachs\n\n
# 1    \n\n    Goldman Sachs\n\n
# 2    \n\n    Goldman Sachs\n\n
# 3    \n\n    Goldman Sachs\n\n
# 4    \n\n    Goldman Sachs\n\n
# 5    \n\n    Goldman Sachs\n\n
# 6    \n\n    Goldman Sachs\n\n
# 7    \n\n    Goldman Sachs\n\n
# 8   \n\n    Morgan Stanley\n\n
# 9    \n\n    Goldman Sachs\n\n
# 10   \n\n    Merrill Lynch\n\n
# 11   \n\n    Goldman Sachs\n\n
# 12   \n\n    Goldman Sachs\n\n
# 13  \n\n    Morgan Stanley\n\n
# 14  \n\n    Morgan Stanley\n\n
# 15  \n\n    Morgan Stanley\n\n
# 16   \n\n    Goldman Sachs\n\n
# 17   \n\n    Goldman Sachs\n\n
# 18   \n\n    Goldman Sachs\n\n
# 19   \n\n    Goldman Sachs\n\n
# 20   \n\n    Goldman Sachs\n\n
#
#                              \nReference Instrument\n \nNotional AmountB\n  \
# 0   \n    iStar Financial, Inc.\n    5.95%, 10/15/...    \n    5,000,000\n
# 1   \n    iStar Financial, Inc.\n    5.95%, 10/15/...    \n    5,000,000\n
# 2    \n    Limited Brands, Inc.\n    6.13%, 12/1/12\n    \n    4,150,000\n
# 3    \n    Limited Brands, Inc.\n    6.13%, 12/1/12\n    \n    4,700,000\n
# 4    \n    Limited Brands, Inc.\n    6.90%, 7/15/17\n   \n    15,000,000\n
# 5      \n    Liz Claiborne, Inc.\n    5.00%, 7/8/13\n   \n    15,000,000\n
# 6      \n    Liz Claiborne, Inc.\n    5.00%, 7/8/13\n   \n    15,000,000\n
# 7             \n    Masco Corp.\n    6.13%, 10/3/16\n   \n    15,000,000\n
# 8            \n    Masco Corp.\n    6.13%, 10/03/16\n    \n    4,500,000\n
# 9   \n    Newell Rubbermaid, Inc.\n    5.50%, 4/15...   \n    30,000,000\n
# 10   \n    Pitney Bowes, Inc. \n    4.63%, 10/01/12\n   \n    25,000,000\n
# 11       \n    RadioShack Corp.\n    7.38%, 5/15/11\n    \n    9,000,000\n
# 12         \n    Realogy Corp.\n    10.50%, 4/15/14\n    \n    5,000,000\n
# 13    \n    Sprint Nextel Corp.\n    6.00%, 12/1/16\n    \n    5,000,000\n
# 14    \n    Sprint Nextel Corp.\n    6.00%, 12/1/16\n   \n    10,000,000\n
# 15    \n    Sprint Nextel Corp.\n    6.00%, 12/1/16\n   \n    13,000,000\n
# 16  \n    Standard Pacific Corp.\n    7.00%, 8/15/...    \n    4,000,000\n
# 17       \n    The Chubb Corp. \n    6.60%, 8/15/18\n   \n    10,000,000\n
# 18        \n    The Chubb Corp.\n    6.60%, 8/15/18\n   \n    10,000,000\n
# 19   \n    TRW Automotive, Inc.\n    7.25%, 3/15/17\n    \n    5,000,000\n
# 20   \n    TRW Automotive, Inc.\n    7.25%, 3/15/17\n    \n    3,000,000\n
#
#    \nPay/Receive(A)\n  \nFixed Rate\n  \nExpirationDate\n \nPaid (Received)\n  \
# 0         \n    Pay\n            5.00   \n    6/20/2013\n     \n    700,000\n
# 1         \n    Pay\n            5.00   \n    6/20/2013\n     \n    725,000\n
# 2         \n    Pay\n            3.38   \n    6/20/2013\n           \n     \n
# 3         \n    Pay\n            2.55   \n    6/20/2013\n           \n     \n
# 4         \n    Pay\n            1.00  \n    12/20/2015\n     \n    679,159\n
# 5         \n    Pay\n            5.00   \n    9/20/2014\n   \n    1,875,000\n
# 6         \n    Pay\n            5.00  \n    12/20/2014\n   \n    1,087,500\n
# 7         \n    Pay\n            1.00  \n    12/20/2015\n   \n    1,047,333\n
# 8         \n    Pay\n            1.00   \n    3/20/2016\n     \n    273,169\n
# 9         \n    Pay\n            1.00   \n    6/20/2014\n     \n    620,488\n
# 10        \n    Pay\n            1.00   \n    3/20/2016\n     \n    562,996\n
# 11        \n    Pay\n            2.27   \n    9/20/2013\n           \n     \n
# 12        \n    Pay\n            5.00   \n    3/20/2016\n     \n    475,000\n
# 13        \n    Pay\n            5.00  \n    12/20/2015\n    \n    (276,094\n
# 14        \n    Pay\n            5.00   \n    3/20/2016\n    \n    (694,225\n
# 15        \n    Pay\n            5.00   \n    6/20/2016\n  \n    (1,097,608\n
# 16    \n    Receive\n            6.70   \n    9/20/2013\n           \n     \n
# 17        \n    Pay\n            1.00  \n    12/20/2014\n    \n    (242,813\n
# 18        \n    Pay\n            1.00   \n    3/20/2015\n    \n    (257,326\n
# 19        \n    Pay\n            5.00   \n    3/20/2015\n      \n    92,579\n
# 20        \n    Pay\n            5.00   \n    6/20/2015\n    \n    (133,100\n
#
#    \nAppreciation/(Depreciation)\n  \
# 0                 \n    (637,805\n
# 1                 \n    (662,805\n
# 2                 \n    (210,815\n
# 3                 \n    (161,222\n
# 4                 \n    (137,202\n
# 5               \n    (1,263,397\n
# 6                 \n    (379,842\n
# 7                 \n    (142,744\n
# 8                   \n    37,179\n
# 9                 \n    (818,684\n
# 10                \n    (351,591\n
# 11                 \n    (71,989\n
# 12                  \n    65,238\n
# 13                \n    (202,601\n
# 14                \n    (239,599\n
# 15                 \n    (92,684\n
# 16                 \n    413,363\n
# 17                 \n    117,740\n
# 18                 \n    137,536\n
# 19                \n    (726,753\n
# 20                \n    (258,426\n
#
#                               \nCredit Event\n   \nRatingC\n
# 0                       \n    Bankruptcy/FTP\n     \n    B\n
# 1   \n    Restructuring/\n    Bankruptcy/FTP\n     \n    B\n
# 2   \n    Restructuring/\n    Bankruptcy/FTP\n   \n    BB+\n
# 3   \n    Restructuring/\n    Bankruptcy/FTP\n   \n    BB+\n
# 4   \n    Restructuring/\n    Bankruptcy/FTP\n   \n    BB+\n
# 5   \n    Restructuring/\n    Bankruptcy/FTP\n     \n    B\n
# 6   \n    Restructuring/\n    Bankruptcy/FTP\n     \n    B\n
# 7                       \n    Bankruptcy/FTP\n   \n    BBB\n
# 8                       \n    Bankruptcy/FTP\n   \n    BBB\n
# 9                       \n    Bankruptcy/FTP\n  \n    BBB-\n
# 10                      \n    Bankruptcy/FTP\n  \n    BBB+\n
# 11                      \n    Bankruptcy/FTP\n    \n    BB\n
# 12                      \n    Bankruptcy/FTP\n     \n    B\n
# 13  \n    Restructuring/\n    Bankruptcy/FTP\n   \n    BB-\n
# 14                      \n    Bankruptcy/FTP\n   \n    BB-\n
# 15                      \n    Bankruptcy/FTP\n   \n    BB-\n
# 16                      \n    Bankruptcy/FTP\n     \n    B\n
# 17                      \n    Bankruptcy/FTP\n    \n    A+\n
# 18                      \n    Bankruptcy/FTP\n    \n    A+\n
# 19                      \n    Bankruptcy/FTP\n   \n    BB+\n
# 20                      \n    Bankruptcy/FTP\n   \n    BB+\n
# Filename ../Data/0001016073_N-CSRS_0000950123-11-081936/table2.csv
#              \nCounterparty\n  \
# 0   \n\n    Goldman Sachs\n\n
# 1   \n\n    Goldman Sachs\n\n
# 2   \n\n    Goldman Sachs\n\n
# 3   \n\n    Goldman Sachs\n\n
# 4   \n\n    Goldman Sachs\n\n
# 5   \n\n    Goldman Sachs\n\n
# 6   \n\n    Goldman Sachs\n\n
# 7   \n\n    Goldman Sachs\n\n
# 8   \n\n    Goldman Sachs\n\n
# 9   \n\n    Goldman Sachs\n\n
# 10  \n\n    Goldman Sachs\n\n
# 11  \n\n    Goldman Sachs\n\n
# 12  \n\n    Goldman Sachs\n\n
# 13  \n\n    Goldman Sachs\n\n
# 14  \n\n    Goldman Sachs\n\n
# 15  \n\n    Goldman Sachs\n\n
# 16  \n\n    Goldman Sachs\n\n
# 17  \n\n    Goldman Sachs\n\n
# 18  \n\n    Goldman Sachs\n\n
#
#                              \nReference Instrument\n \nNotional AmountB\n  \
# 0   \n    Alcatel-Lucent USA, Inc.\n    6.50%, 1/1...   \n    15,000,000\n
# 1   \n    Alcatel-Lucent USA, Inc. \n    6.50%, 1/...    \n    5,000,000\n
# 2   \n    Boston Properties L.P. \n    6.25%, 1/15...   \n    11,000,000\n
# 3         \n    Brunswick Corp. \n    7.13%, 8/1/27\n   \n    10,000,000\n
# 4          \n    Brunswick Corp.\n    7.13%, 8/1/27\n   \n    10,000,000\n
# 5           \n    Centex Corp. \n    5.25%, 6/15/15\n    \n    5,000,000\n
# 6   \n    Continental Airlines, Inc. \n    5.00%, ...    \n    1,000,000\n
# 7   \n    Continental Airlines, Inc. \n    5.00%, ...      \n    500,000\n
# 8   \n    Continental Airlines, Inc. \n    5.00%, ...    \n    1,000,000\n
# 9     \n    CVS Caremark Corp. \n    4.88%, 9/15/14\n   \n    10,000,000\n
# 10  \n    Dow Jones CDX NA\n    High Yield Series ...    \n    7,830,000\n
# 11  \n    Dow Jones CDX NA\n    Investment Grade S...    \n    2,420,000\n
# 12  \n    Eastman Kodak\n    Co.D \n\n    7.25%, 1...   \n    15,000,000\n
# 13     \n    Eastman Kodak Co.\n    7.25%, 11/15/13\n   \n    15,000,000\n
# 14   \n    Enbridge Energy, L.P.\n    4.75%, 6/1/13\n   \n    10,000,000\n
# 15       \n    First Data Corp.\n    9.88%, 9/24/15\n    \n    5,000,000\n
# 16         \n    H.J. Heinz Co.\n    6.38%, 7/15/28\n   \n    10,000,000\n
# 17  \n    iStar Financial, Inc.\n    6.00%, 12/15/...    \n    4,000,000\n
# 18  \n    iStar Financial, Inc.\n    6.00%, 12/15/...    \n    4,000,000\n
#
#    \nPay/Receive(A)\n  \nFixed Rate\n  \nExpirationDate\n \nPaid (Received)\n  \
# 0         \n    Pay\n            5.00   \n    9/20/2012\n    \n    (480,584\n
# 1         \n    Pay\n            5.00  \n    12/20/2012\n    \n    (278,812\n
# 2         \n    Pay\n            1.00   \n    9/20/2014\n     \n    848,323\n
# 3         \n    Pay\n            5.00  \n    12/20/2014\n      \n    40,542\n
# 4         \n    Pay\n            5.00  \n    12/20/2014\n    \n    (143,212\n
# 5         \n    Pay\n            4.21   \n    3/20/2013\n           \n     \n
# 6     \n    Receive\n            5.00   \n    6/20/2013\n    \n    (400,000\n
# 7     \n    Receive\n            4.93   \n    6/20/2012\n           \n     \n
# 8     \n    Receive\n            5.00   \n    6/20/2013\n    \n    (290,000\n
# 9         \n    Pay\n            1.00   \n    9/20/2014\n    \n    (286,840\n
# 10        \n    Pay\n            5.00  \n    12/20/2013\n   \n    2,158,144\n
# 11    \n    Receive\n            0.35   \n    6/20/2012\n     \n    (34,974\n
# 12        \n    Pay\n            5.00   \n    9/20/2014\n   \n    3,000,000\n
# 13    \n    Receive\n            5.00   \n    9/20/2016\n  \n    (4,200,000\n
# 14        \n    Pay\n            1.00   \n    6/20/2015\n      \n    56,732\n
# 15        \n    Pay\n            5.00   \n    6/20/2016\n     \n    350,000\n
# 16        \n    Pay\n            1.00   \n    9/20/2014\n    \n    (320,193\n
# 17        \n    Pay\n            5.50   \n    3/20/2013\n           \n     \n
# 18        \n    Pay\n            5.05   \n    6/20/2013\n           \n     \n
#
#    \nAppreciation/(Depreciation)\n  \
# 0                 \n    (258,109\n
# 1                    \n    6,671\n
# 2                 \n    (956,808\n
# 3               \n    (1,005,442\n
# 4                 \n    (821,688\n
# 5                 \n    (270,893\n
# 6                  \n    394,192\n
# 7                    \n    1,843\n
# 8                  \n    284,192\n
# 9                   \n    89,334\n
# 10              \n    (2,657,391\n
# 11                  \n    34,506\n
# 12                \n    (322,917\n
# 13                 \n    142,923\n
# 14                \n    (183,142\n
# 15                  \n    46,774\n
# 16                  \n    95,207\n
# 17                   \n    2,074\n
# 18                  \n    46,186\n
#
#                               \nCredit Event\n   \nRatingC\n
# 0                       \n    Bankruptcy/FTP\n     \n    B\n
# 1                       \n    Bankruptcy/FTP\n     \n    B\n
# 2                       \n    Bankruptcy/FTP\n    \n    A-\n
# 3                       \n    Bankruptcy/FTP\n     \n    B\n
# 4   \n    Restructuring/\n    Bankruptcy/FTP\n     \n    B\n
# 5                       \n    Bankruptcy/FTP\n   \n    BB-\n
# 6                       \n    Bankruptcy/FTP\n     \n    B\n
# 7                       \n    Bankruptcy/FTP\n     \n    B\n
# 8                       \n    Bankruptcy/FTP\n     \n    B\n
# 9                       \n    Bankruptcy/FTP\n  \n    BBB+\n
# 10                      \n    Bankruptcy/FTP\n   \n    CCC\n
# 11                      \n    Bankruptcy/FTP\n   \n    BBB\n
# 12                      \n    Bankruptcy/FTP\n   \n    CCC\n
# 13                      \n    Bankruptcy/FTP\n   \n    CCC\n
# 14                      \n    Bankruptcy/FTP\n   \n    BBB\n
# 15                      \n    Bankruptcy/FTP\n    \n    B-\n
# 16                      \n    Bankruptcy/FTP\n   \n    BBB\n
# 17                      \n    Bankruptcy/FTP\n     \n    B\n
# 18                      \n    Bankruptcy/FTP\n     \n    B\n
# Filename ../Data/0001016073_N-CSRS_0000950123-11-081936/table1.csv
#     NotionalAmount ExpirationDate                  Counterparty  \
# 0          1750000       10/12/52          Bank of America N.A.
# 1          6575000       10/12/52          Bank of America N.A.
# 2           325000        6/20/14             Barclays Bank PLC
# 3           600000        6/20/16             Barclays Bank PLC
# 4           600000        6/20/16             Barclays Bank PLC
# 5           600000        6/20/16             Barclays Bank PLC
# 6           469483        7/25/45  Credit Suisse Securities LLC
# 7          1500000       10/12/52           Goldman Sachs & Co.
# 8          5100000       10/12/52           Goldman Sachs & Co.
# 9          1075000       10/12/52           Goldman Sachs & Co.
# 10         2000000       10/12/52           Goldman Sachs & Co.
#
#    Buy/SellProtection Receive(Pay)FixedRate Deliverable on Default  \
# 0                 Buy                (0.100          CMBX.NA.AAA.1
# 1                 Buy                (0.500           CMBX.NA.AM.1
# 2                 Buy                (1.000           Centex Corp.
# 3                 Buy                (1.000       Kingdom of Spain
# 4                 Buy                (1.000       Kingdom of Spain
# 5                 Buy                (1.000       Kingdom of Spain
# 6                 Buy                (0.180        ABX.HE.AAA.06-1
# 7                 Buy                (0.100          CMBX.NA.AAA.1
# 8                 Buy                (0.100          CMBX.NA.AAA.1
# 9                 Buy                (0.100          CMBX.NA.AAA.1
# 10                Buy                (0.100          CMBX.NA.AAA.1
#
#    UnrealizedAppreciation(Depreciation)  Premium(Received)Paid   Value
# 0                               (41,869                  84219   42350
# 1                              (251,822                 526000  274178
# 2                                (1,169                   6019    4850
# 3                                  1118                  35571   36689
# 4                                (1,399                  38088   36689
# 5                                (4,965                  41653   36688
# 6                                (6,059                  48124   42065
# 7                              (113,700                 150000   36300
# 8                              (369,705                 493125  123420
# 9                               (43,860                  69875   26015
# 10                              (46,600                  95000   48400
# Filename ../Data/0000927972_N-CSRS_0001193125-11-183930/table4.csv
#    NotionalAmount ExpirationDate          Counterparty Buy/SellProtection  \
# 0         1650000       10/12/52   Goldman Sachs & Co.                Buy
# 1         1650000       10/12/52   Goldman Sachs & Co.                Buy
# 2         1650000       10/12/52   Goldman Sachs & Co.                Buy
# 3         3300000       10/12/52   Goldman Sachs & Co.                Buy
# 4          600000        6/20/16  JP Morgan Chase Bank                Buy
# 5         1200000        6/20/16  JP Morgan Chase Bank                Buy
#
#   Receive(Pay)FixedRate Deliverable on Default  \
# 0                (0.100          CMBX.NA.AAA.1
# 1                (0.500           CMBX.NA.AM.1
# 2                (0.500           CMBX.NA.AM.1
# 3                (0.500           CMBX.NA.AM.1
# 4                (1.000       Kingdom of Spain
# 5                (1.000       Kingdom of Spain
#
#   UnrealizedAppreciation(Depreciation)  Premium(Received)Paid   Value
# 0                              (59,758                  99688   39930
# 1                              (50,820                 119625   68805
# 2                              (50,820                 119625   68805
# 3                             (101,640                 239250  137610
# 4                               (1,399                  38088   36689
# 5                                 1719                  71659   73378
# Filename ../Data/0000927972_N-CSRS_0001193125-11-183930/table7.csv
#    NotionalAmount ExpirationDate         Counterparty  \
# 0         1700000        6/14/11  Goldman Sachs & Co.
#
#                                Payments Made by Fund  \
# 0  Absolute value of [(USD-CMM30-FNMA rate - USD-...
#
#                            Payments Received by Fund  \
# 0  Absolute value of [(USD-CMM30-FNMA rate - USD-...
#
#    UnrealizedAppreciation(Depreciation) PremiumReceived(Paid)  Value
# 0                                  2753                     -   2753
# Filename ../Data/0000927972_N-CSRS_0001193125-11-183930/table14.csv
#    NotionalAmount ExpirationDate         Counterparty  \
# 0        10950000        6/14/11  Goldman Sachs & Co.
#
#                                Payments Made by Fund  \
# 0  Absolute value of [(USD-CMM30-FNMA rate - USD-...
#
#                            Payments Received by Fund  \
# 0  Absolute value of [(USD-CMM30-FNMA rate - USD-...
#
#    UnrealizedAppreciation(Depreciation) PremiumReceived(Paid)  Value
# 0                                 17735                     -  17735
# Filename ../Data/0000927972_N-CSRS_0001193125-11-183930/table12.csv
#     NotionalAmount ExpirationDate                  Counterparty  \
# 0           180000        6/20/16  Credit Suisse Securities LLC
# 1            50560        7/25/45  Credit Suisse Securities LLC
# 2           646000       10/12/52           Goldman Sachs & Co.
# 3           190000       10/12/52           Goldman Sachs & Co.
# 4            75000       10/12/52           Goldman Sachs & Co.
# 5           125000       10/12/52           Goldman Sachs & Co.
# 6           175000       10/12/52           Goldman Sachs & Co.
# 7           175000       10/12/52           Goldman Sachs & Co.
# 8           175000       10/12/52           Goldman Sachs & Co.
# 9           335000       10/12/52           Goldman Sachs & Co.
# 10           65000        6/20/16         JP Morgan Chase Bank
# 11          125000        6/20/16         JP Morgan Chase Bank
#
#    Buy/SellProtection Receive(Pay)FixedRate        Deliverable on Default  \
# 0                 Buy                (0.580  Marriott International, Inc.
# 1                 Buy                (0.180               ABX.HE.AAA.06-1
# 2                 Buy                (0.100                 CMBX.NA.AAA.1
# 3                 Buy                (0.100                 CMBX.NA.AAA.1
# 4                 Buy                (0.100                 CMBX.NA.AAA.1
# 5                 Buy                (0.100                 CMBX.NA.AAA.1
# 6                 Buy                (0.100                 CMBX.NA.AAA.1
# 7                 Buy                (0.500                  CMBX.NA.AM.1
# 8                 Buy                (0.500                  CMBX.NA.AM.1
# 9                 Buy                (0.500                  CMBX.NA.AM.1
# 10                Buy                (1.000              Kingdom of Spain
# 11                Buy                (1.000              Kingdom of Spain
#
#    UnrealizedAppreciation(Depreciation) Premium(Received)Paid  Value
# 0                                  3965                     -   3965
# 1                                  (652                  5182   4530
# 2                               (46,829                 62462  15633
# 3                               (14,402                 19000   4598
# 4                                (3,060                  4875   1815
# 5                                (2,913                  5938   3025
# 6                                (6,338                 10573   4235
# 7                                (5,390                 12687   7297
# 8                                (5,390                 12687   7297
# 9                               (10,318                 24288  13970
# 10                                 (152                  4126   3974
# 11                                  179                  7465   7644
# Filename ../Data/0000927972_N-CSRS_0001193125-11-183930/table13.csv
#     NotionalAmount ExpirationDate                  Counterparty  \
# 0          4020000        6/20/16  Credit Suisse Securities LLC
# 1          1444564        7/25/45  Credit Suisse Securities LLC
# 2         17000000       10/12/52           Goldman Sachs & Co.
# 3          5000000       10/12/52           Goldman Sachs & Co.
# 4          2500000       10/12/52           Goldman Sachs & Co.
# 5          4175000       10/12/52           Goldman Sachs & Co.
# 6          5100000       10/12/52           Goldman Sachs & Co.
# 7          4825000       10/12/52           Goldman Sachs & Co.
# 8          4825000       10/12/52           Goldman Sachs & Co.
# 9          9650000       10/12/52           Goldman Sachs & Co.
# 10         1625000        6/20/16         JP Morgan Chase Bank
# 11         3000000        6/20/16         JP Morgan Chase Bank
#
#    Buy/SellProtection Receive(Pay)FixedRate        Deliverable on Default  \
# 0                 Buy                (0.580  Marriott International, Inc.
# ...
# 17                                 (19,022                  (272,899
# 18                                 (26,408                   834,063
#
#     UnrealizedDepreciation($)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# Filename ../Data/0001352280_N-CSRS_0001193125-13-199002/table1.csv
#   \nEffective/\nExpiration Date\n \nNotional Amount ($) (f)\n  \
# 0       \n9/20/2012\n12/20/2017\n                   2,500,000
# 1       \n9/20/2012\n12/20/2017\n                   2,500,000
#
#    \nFixed Cash Flows Received\n  \
# 0                            1.0
# 1                            1.0
#
#   \nUnderlying Debt Obligation/ Quality Rating (g)\n \nValue ($)\n  \
# 0        \nKingdom of Spain, 5.5%, 7/30/2017, BBB-\n      (203,501
# 1        \nKingdom of Spain, 5.5%, 7/30/2017, BBB-\n      (203,502
#
#   \nUpfront Payments Received ($)\n \nUnrealized Appreciation ($)\n
# 0                          (300,303                          96,802
# 1                          (267,058                          63,556
# Filename ../Data/0000747677_N-CSRS_0000088053-13-000656/table3.csv
#            Underlying Instrument         Counterparty Expiration Date  \
# 0  Federative Republic of Brazil  JPMorgan Chase Bank         9/20/16
# 1  Federative Republic of Brazil    Barclays Bank PLC         6/20/18
# 2  Federative Republic of Brazil  JPMorgan Chase Bank         6/20/18
# 3  Federative Republic of Brazil    Barclays Bank PLC         6/20/20
# 4  Federative Republic of Brazil   Barclays Bank\nPLC         6/20/20
# 5  Federative Republic of Brazil    Barclays Bank PLC         6/20/20
# 6  Federative Republic of Brazil   Barclays Bank\nPLC         6/20/20
# 7      Peoples Republic of China  JPMorgan Chase Bank         9/20/16
# 8      Peoples Republic of China  JPMorgan Chase Bank         9/20/16
#
#    Notional Amount  Fixed Rate (%)
# 0           550000               1
# 1           300000               1
# 2           500000               1
# 3           500000               1
# 4           500000               1
# 5           275000               1
# 6           250000               1
# 7           500000               1
# 8           500000               1
# Filename ../Data/0000798290_N-CSRS_0001206774-15-002139/table4.csv
#                           \nCounterparty\n  \
# 0  \n\n    Goldman Sachs International\n\n
# 1  \n\n    Goldman Sachs International\n\n
# 2  \n\n    Goldman Sachs International\n\n
# 3  \n\n    Goldman Sachs International\n\n
#
#                                 \nReference Entity\n \nBuy/Sell Protection\n  \
# 0                              \n    Calpine Corp.\n            \n    Sell\n
# 1                              \n    Calpine Corp.\n            \n    Sell\n
# 2  \n    Texas\n    Competitive\n    Electric\n  ...            \n    Sell\n
# 3  \n    Texas\n    Competitive\n    Electric\n  ...            \n    Sell\n
#
#    \nFixed Rate\n \nExpiration Date\n  \nAmount (000)\n
# 0            5.00    \n    03/20/10\n  \n    1,500\n000
# 1            5.00    \n    03/20/11\n  \n    2,000\n000
# 2            2.85    \n    06/20/10\n  \n    5,000\n000
# 3            5.00    \n    06/20/10\n  \n    3,000\n000
# Filename ../Data/0000853180_N-CSRS_0000950123-10-030848/table2.csv
#     \nCounterparty\n             \nReference Entity\n  \
# 0  \nCitibank N.A.\n  \nCommonwealth of Puerto Rico\n
#
#   \nBuy/Sell Protection (9)\n \nCredit Spread (10)\n \nNotional Amount\n  \
# 0                     \nBuy\n              \n25.5%\n       \n1,810,000\n
#
#   \nFixed Rate\n \nTermination Date\n
# 0     \n5.000%\n         \n12/20/19\n
# Filename ../Data/0000899761_N-CSRS_0000891804-15-000105/table2.csv
#        Counterparty  Notional amount Terminationdate Payments made bythe Fund  \
# 0  Deutsche Bank AG          2500000        08/25/37                      (1)
# 1     Merrill Lynch          1650000        08/25/37                      (1)
#
#    Payments receivedby the Fund
# 0                          0.09
# 1                          0.09
# Filename ../Data/0000944684_N-CSRS_0001193125-08-191895/table3.csv
#    Expiration    Counterparty  \
# 0  03/20/2009        CitiBank
# 1  03/20/2009   Goldman Sachs
# 2  09/20/2010   Goldman Sachs
# 3  06/20/2012  Morgan Stanley
# 4  06/20/2012  Morgan Stanley
# 5  09/20/2012  Morgan Stanley
# 6  12/13/2049  Morgan Stanley
# 7  02/25/2051   Goldman Sachs
# 8  12/25/2051   Goldman Sachs
#
#   Reference Debt \n        Obligation/ \n        Index  \
# 0                            AIG, 6.25%,\n05/01/2036
# 1                 Morgan Stanley, 6.60%,\n04/01/2012
# 2              Duke Realty, Ltd., 5.40%,\n08/15/2014
# 3  Dow Jones CDX, North\nAmerican Investment Grad...
# 4                     PG&E Corp., 4.80%,\n03/01/2014
# 5              Duke Realty, Ltd.,\n5.40%, 08/15/2014
# 6                        CMBX North America AA Index
# 7                        CMBX North America AA Index
# 8                        CMBX North America AA Index
#
#   Notional \n        Amount  \
# 0                12,000,000
# 1                 8,000,000
# 2                 8,000,000
# 3                15,744,000
# 4                10,000,000
# 5                 8,000,000
# 6                 4,200,000
# 7                22,000,000
# 8                24,500,000
#
#    Fixed \n        Payments \n        Made by \n        the Fund  \
# 0                                               1.55
# 1                                               1.75
# 2                                               0.75
# 3                                               0.35
# 4                                               0.24
# 5                                               0.90
# 6                                               0.27
# 7                                               1.75
# 8                                               1.65
#
#   Frequency of \n        Payments \n        Made  \
# 0                                      Quarterly
# 1                                      Quarterly
# 2                                      Quarterly
# 3                                      Quarterly
# 4                                      Quarterly
# 5                                      Quarterly
# 6                                        Monthly
# 7                                        Monthly
# 8                                        Monthly
#
#   Unrealized \n        Gain (Loss)
# 0                         (794,180
# 1                         (120,807
# 2                         (813,533
# 3                         (907,902
# 4                         (689,348
# 5                       (1,562,138
# 6                       (1,808,594
# 7                       (5,827,151
# 8                      (10,437,677
# Filename ../Data/0001046232_N-CSRS_0001133228-09-000012/table6.csv
#   Underlying Instrument       Counterparty NotionalAmount  FixedRate  \
# 0          Target Corp.  Barclays Bank PLC     $2,000,000        1.0
#
#   ExpirationDate  ImpliedCreditSpread* UpfrontPaymentsMade      Value  \
# 0       06/20/19                 4.628           $(55,362)  $(51,630)
#
#   UnrealizedAppreciation
# 0                 $3,732
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table5.csv
#   Underlying Instrument                 Broker (Exchange) NotionalAmount  \
# 0          CDX.NA.HY.22  Credit Suisse First Boston (CME)     13,365,000
# 1          CDX.NA.HY.22                    JPMorgan (CME)      8,415,000
#
#    FixedRate ExpirationDate  ImpliedCreditSpread*     Value  \
# 0        5.0       06/20/19                35.317  $808,692
# 1        5.0       06/20/19                35.317   509,176
#
#   UnrealizedDepreciation
# 0                (46,322
# 1                (40,948
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table4.csv
#   Underlying Instrument       Counterparty NotionalAmount  FixedRate  \
# 0          Target Corp.  Barclays Bank PLC     $2,000,000        1.0
#
#   ExpirationDate  ImpliedCreditSpread* UpfrontPaymentsMade      Value  \
# 0       06/20/19                 4.628           $(55,362)  $(51,630)
#
#   UnrealizedAppreciation
# 0                 $3,732
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table6.csv
#   Underlying Instrument Counterparty NotionalAmount  FixedRate ExpirationDate  \
# 0          Kohl s Corp.     JPMorgan     $2,000,000        1.0       09/20/19
#
#    ImpliedCreditSpread* UpfrontPaymentsMade     Value UnrealizedAppreciation
# 0                10.246           $(18,512)  $(2,335)                $16,177
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table7.csv
#   Underlying Instrument                 Broker (Exchange) NotionalAmount  \
# 0          CDX.NA.HY.22  Credit Suisse First Boston (CME)    $13,365,000
# 1          CDX.NA.HY.22                    JPMorgan (CME)      8,415,000
#
#    FixedRate ExpirationDate  ImpliedCreditSpread*     Value  \
# 0        5.0       06/20/19                35.317  $808,692
# 1        5.0       06/20/19                35.317   509,176
#
#   UnrealizedDepreciation
# 0               $(46,322
# 1                (40,948
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table3.csv
#   Underlying Instrument Counterparty NotionalAmount  FixedRate  \
# 0          Kohl s Corp.     JPMorgan        $75,000        1.0
#
#   Expiration Date  ImpliedCreditSpread* UpfrontPaymentMade Value  \
# 0        09/20/19                10.246              $(694  $(88
#
#   UnrealizedAppreciation
# 0                   $606
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table2.csv
#   Underlying Instrument       Counterparty NotionalAmount  FixedRate  \
# 0          Target Corp.  Barclays Bank PLC        $75,000        1.0
#
#   Expiration Date  ImpliedCreditSpread* UpfrontPaymentMade    Value  \
# 0        06/20/19                 4.628            $(2,076  $(1,936
#
#   UnrealizedAppreciation
# 0                   $140
# Filename ../Data/0000883939_N-CSRS_0001193125-14-434389/table1.csv
#          Swap Counterparty and Reference Obligation Buy/Sell Protection  \
# 0                   Goodrich Corp., 7.63%, 12/15/12                 Buy
# 1                   Goodrich Corp., 7.63%, 12/15/12                 Buy
# 2                   Nordstrom, Inc., 6.95%, 3/15/28                 Buy
# 3                      Pactiv Corp., 8.13%, 6/15/17                 Buy
# 4                  Sealed Air Corp., 5.63%, 7/15/13                 Buy
# 5                  Sealed Air Corp., 5.63%, 7/15/13                 Buy
# 6            Textron Financial Corp., 5.13%, 2/3/11                 Buy
# 7   Toll Brothers Finance Corp., 6.88%,\n  11/15/12                 Buy
# 8   Toll Brothers Finance Corp., 6.88%,\n  11/15/12                 Buy
# 9               The Walt Disney Co., 6.65%, 1/15/28                 Buy
# 10                     Eaton Corp., 7.65%, 11/15/29                 Buy
# 11                            ABX HE-AAA 06-1 Index                 Buy
# 12           Arrow Electronics, Inc., 6.88%, 6/1/18                 Buy
# 13           Arrow Electronics, Inc., 6.88%, 6/1/18                 Buy
# 14                     Pactiv Corp., 8.13%, 6/15/17                 Buy
# 15          Dow Jones CDX North American Investment                 Buy
# 16                     Pactiv Corp., 8.13%, 6/15/17                 Buy
# 17       American Standard, Inc., 7.63%,\n  2/15/10                 Buy
# 18       American Standard, Inc., 7.63%,\n  2/15/10                 Buy
# 19   AvalonBay Communities, Inc., 6.13%,\n  11/1/12                 Buy
# 20   AvalonBay Communities, Inc., 6.13%,\n  11/1/12                 Buy
# 21                   Carnival Corp., 6.65%, 1/15/28                 Buy
# 22   Coca-Cola Enterprises, Inc., 6.13%,\n  8/15/11                 Buy
# 23          Dow Jones CDX North American Investment                Sell
# 24                     Eaton Corp., 7.65%, 11/15/29                 Buy
# 25                     Eaton Corp., 7.38%, 11/15/31                 Buy
# 26                  Goodrich Corp., 7.63%, 12/15/12                 Buy
# 27           Merrill Lynch & Co., 5.00%,\n  1/15/15                 Buy
# 28                          ProLogis, 5.50%, 3/1/13                 Buy
# 29                          ProLogis, 5.50%, 3/1/13                 Buy
# 30                 Sealed Air Corp., 5.63%, 7/15/13                 Buy
# 31                 Sealed Air Corp., 5.63%, 7/15/13                 Buy
# 32           Textron Financial Corp., 5.13%, 2/3/11                 Buy
# 33           Merrill Lynch & Co., 5.00%,\n  1/15/15                 Buy
# 34                  Nordstrom, Inc., 6.95%, 3/15/28                 Buy
# 35                  Nordstrom, Inc., 6.95%, 3/15/28                 Buy
# 36     Pepsi Bottling Group, Inc., 7.00%,\n  3/1/29                 Buy
# 37     Pepsi Bottling Group, Inc., 7.00%,\n  3/1/29                 Buy
#
#    Amount (000)  Pay/Receive Fixed Rate Termination Date
# 0      $  60000                    0.70          3/20/13
# 1         45000                    0.82          3/20/18
# 2         60000                    1.03          3/20/18
# 3        140000                    1.38          3/20/13
# 4         30000                    1.08          3/20/18
# 5         40000                    1.12          3/20/18
# 6         75000                    0.80          3/20/18
# 7         40000                    2.25          3/20/18
# 8         80000                    2.90          3/20/13
# 9        230000                    0.77          3/20/13
# 10       120000                    0.82          3/20/18
# 11        90000                    0.18          7/25/45
# 12       100000                    1.00          3/20/15
# 13       125000                    1.11          3/20/13
# 14       140000                    1.35          3/20/13
# 15        85000                    5.00          6/20/13
# 16        40000                    1.34          3/20/13
# 17        30000                    0.50          3/20/18
# 18        15000                    0.60          3/20/18
# 19       140000                    2.20          6/20/13
# 20       155000                    3.05          3/20/13
# 21        95000                    1.57          3/20/18
# 22       160000                    0.59          3/20/13
# 23        90000                    1.40         12/20/12
# 24        50000                    0.97          3/20/18
# 25       150000                    1.25          3/20/13
# 26        50000                    0.47          3/20/18
# 27        85000                    2.45         12/20/12
# 28        90000                    2.97          6/20/13
# 29        70000                    3.33          3/20/13
# 30        60000                    1.08          3/20/18
# 31        30000                    1.24          3/20/18
# 32       125000                    1.05          3/20/13
# 33        80000                    2.30          3/20/13
# 34        50000                    1.07          3/20/18
# 35        50000                    1.15          3/20/18
# 36        40000                    0.58          3/20/13
# 37        55000                    0.63          3/20/13
# Filename ../Data/0000921187_N-CSRS_0001104659-08-057223/table2.csv
